# %%
import json
import requests
from pprint import pprint
import pandas as pd

# %%
base_url="http://crashviewer.nhtsa.dot.gov/CrashAPI/crashes/GetCaseList?"

params = {
    'states':'04',
    'fromYear':'',
    'toYear':'',
    'minNumOfVehicles':'1',
    'maxNumOfVehicles':'10',
    'format':'json'
}

response = requests.get(base_url,params=params)

years = ['2014','2015','2016','2017','2018']

county=[]
CrashDate=[]
Fatals=[]
TotalVehicles=[]

for year in years:
    params['fromYear'] = year
    params['toYear'] = year
    
    response = requests.get(base_url,params=params).json()
   
    for county_name in response['Results'][0]:
        county.append(county_name["CountyName"])
        CrashDate.append(county_name["CrashDate"])
        Fatals.append(county_name["Fatals"])
        TotalVehicles.append(county_name["TotalVehicles"])
county
# Out:
# ['PIMA (19)',
#  'PIMA (19)',
#  'MARICOPA (13)',
#  'LA PAZ (12)',
#  'COCONINO (5)',
#  'PIMA (19)',
#  'MARICOPA (13)',
#  'YAVAPAI (25)',
#  'MARICOPA (13)',
#  'PINAL (21)',
#  'YUMA (27)',
#  'COCONINO (5)',
#  'COCONINO (5)',
#  'PIMA (19)',
#  'YAVAPAI (25)',
#  'PIMA (19)',
#  'COCONINO (5)',
#  'PIMA (19)',
#  'MARICOPA (13)',
#  'PINAL (21)',
#  'MARICOPA (13)',
#  'PINAL (21)',
#  'MARICOPA (13)',
#  'LA PAZ (12)',
#  'PIMA (19)',
#  'NAVAJO (17)',
#  'YUMA (27)',
#  'PIMA (19)',
#  'PIMA (19)',
#  'PIMA (19)',
#  'YUMA (27)',
#  'GILA (7)',
#  'MARICOPA (13)',
#  'PIMA (19)',
#  'YUMA (27)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'COCHISE (3)',
#  'GRAHAM (9)',
#  'PIMA (19)',
#  'YUMA (27)',
#  'GILA (7)',
#  'PIMA (19)',
#  'COCONINO (5)',
#  'APACHE (1)',
#  'GILA (7)',
#  'PIMA (19)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'COCONINO (5)',
#  'PIMA (19)',
#  'SANTA CRUZ (23)',
#  'SANTA CRUZ (23)',
#  'MARICOPA (13)',
#  'PIMA (19)',
#  'PIMA (19)',
#  'MARICOPA (13)',
#  'YUMA (27)',
#  'MARICOPA (13)',
#  'PIMA (19)',
#  'PINAL (21)',
#  'YUMA (27)',
#  'SANTA CRUZ (23)',
#  'PIMA (19)',
#  'MARICOPA (13)',
#  'PINAL (21)',
#  'MARICOPA (13)',
#  'PIMA (19)',
#  'MARICOPA (13)',
#  'YAVAPAI (25)',
#  'MARICOPA (13)',
#  'YAVAPAI (25)',
#  'YAVAPAI (25)',
#  'YAVAPAI (25)',
#  'MARICOPA (13)',
#  'COCONINO (5)',
#  'COCONINO (5)',
#  'MARICOPA (13)',
#  'PINAL (21)',
#  'GILA (7)',
#  'PIMA (19)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'COCONINO (5)',
#  'PINAL (21)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'COCONINO (5)',
#  'APACHE (1)',
#  'LA PAZ (12)',
#  'MARICOPA (13)',
#  'APACHE (1)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'YUMA (27)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'PIMA (19)',
#  'COCONINO (5)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'PINAL (21)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'COCHISE (3)',
#  'MARICOPA (13)',
#  'PIMA (19)',
#  'YUMA (27)',
#  'NAVAJO (17)',
#  'PINAL (21)',
#  'PIMA (19)',
#  'YUMA (27)',
#  'MARICOPA (13)',
#  'MOHAVE (15)',
#  'PIMA (19)',
#  'PIMA (19)',
#  'YAVAPAI (25)',
#  'APACHE (1)',
#  'PIMA (19)',
#  'YAVAPAI (25)',
#  'MOHAVE (15)',
#  'YAVAPAI (25)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'PINAL (21)',
#  'NAVAJO (17)',
#  'LA PAZ (12)',
#  'MARICOPA (13)',
#  'PINAL (21)',
#  'MARICOPA (13)',
#  'APACHE (1)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'MOHAVE (15)',
#  'APACHE (1)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'PINAL (21)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'NAVAJO (17)',
#  'PIMA (19)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'COCONINO (5)',
#  'MARICOPA (13)',
#  'PIMA (19)',
#  'PINAL (21)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'PINAL (21)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'YAVAPAI (25)',
#  'MARICOPA (13)',
#  'APACHE (1)',
#  'NAVAJO (17)',
#  'MARICOPA (13)',
#  'NAVAJO (17)',
#  'YUMA (27)',
#  'MARICOPA (13)',
#  'APACHE (1)',
#  'APACHE (1)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'PIMA (19)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'COCONINO (5)',
#  'APACHE (1)',
#  'NAVAJO (17)',
#  'APACHE (1)',
#  'COCHISE (3)',
#  'YUMA (27)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'MOHAVE (15)',
#  'YUMA (27)',
#  'MARICOPA (13)',
#  'GILA (7)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'COCHISE (3)',
#  'PIMA (19)',
#  'PIMA (19)',
#  'SANTA CRUZ (23)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'PIMA (19)',
#  'COCONINO (5)',
#  'YAVAPAI (25)',
#  'PIMA (19)',
#  'YAVAPAI (25)',
#  'COCHISE (3)',
#  'PIMA (19)',
#  'COCONINO (5)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'YAVAPAI (25)',
#  'MARICOPA (13)',
#  'PIMA (19)',
#  'YUMA (27)',
#  'PIMA (19)',
#  'GILA (7)',
#  'MARICOPA (13)',
#  'COCHISE (3)',
#  'YUMA (27)',
#  'YAVAPAI (25)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'MOHAVE (15)',
#  'MARICOPA (13)',
#  'MOHAVE (15)',
#  'COCONINO (5)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'PINAL (21)',
#  'GILA (7)',
#  'MOHAVE (15)',
#  'MARICOPA (13)',
#  'PIMA (19)',
#  'MOHAVE (15)',
#  'MARICOPA (13)',
#  'PIMA (19)',
#  'MARICOPA (13)',
#  'PINAL (21)',
#  'MARICOPA (13)',
#  'PINAL (21)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'MOHAVE (15)',
#  'PIMA (19)',
#  'YAVAPAI (25)',
#  'MARICOPA (13)',
#  'YAVAPAI (25)',
#  'PIMA (19)',
#  'YAVAPAI (25)',
#  'MARICOPA (13)',
#  'SANTA CRUZ (23)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'PIMA (19)',
#  'MARICOPA (13)',
#  'PIMA (19)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'NAVAJO (17)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'NAVAJO (17)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'NAVAJO (17)',
#  'APACHE (1)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'MOHAVE (15)',
#  'MARICOPA (13)',
#  'APACHE (1)',
#  'NAVAJO (17)',
#  'YUMA (27)',
#  'MARICOPA (13)',
#  'GILA (7)',
#  'YAVAPAI (25)',
#  'APACHE (1)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'NAVAJO (17)',
#  'MARICOPA (13)',
#  'NAVAJO (17)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'YAVAPAI (25)',
#  'PIMA (19)',
#  'MOHAVE (15)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'YAVAPAI (25)',
#  'PIMA (19)',
#  'COCONINO (5)',
#  'MARICOPA (13)',
#  'APACHE (1)',
#  'MARICOPA (13)',
#  'PIMA (19)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'MOHAVE (15)',
#  'YUMA (27)',
#  'COCHISE (3)',
#  'COCONINO (5)',
#  'COCONINO (5)',
#  'NAVAJO (17)',
#  'GRAHAM (9)',
#  'LA PAZ (12)',
#  'MOHAVE (15)',
#  'MARICOPA (13)',
#  'PINAL (21)',
#  'MARICOPA (13)',
#  'PINAL (21)',
#  'MARICOPA (13)',
#  'PIMA (19)',
#  'MARICOPA (13)',
#  'GILA (7)',
#  'MARICOPA (13)',
#  'GILA (7)',
#  'MARICOPA (13)',
#  'PIMA (19)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'PIMA (19)',
#  'COCONINO (5)',
#  'NAVAJO (17)',
#  'MARICOPA (13)',
#  'LA PAZ (12)',
#  'PIMA (19)',
#  'PIMA (19)',
#  'MARICOPA (13)',
#  'COCONINO (5)',
#  'NAVAJO (17)',
#  'MARICOPA (13)',
#  'MOHAVE (15)',
#  'YAVAPAI (25)',
#  'PIMA (19)',
#  'PIMA (19)',
#  'NAVAJO (17)',
#  'YUMA (27)',
#  'MARICOPA (13)',
#  'COCONINO (5)',
#  'YAVAPAI (25)',
#  'YAVAPAI (25)',
#  'MARICOPA (13)',
#  'APACHE (1)',
#  'COCONINO (5)',
#  'MARICOPA (13)',
#  'MOHAVE (15)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'COCONINO (5)',
#  'MARICOPA (13)',
#  'MOHAVE (15)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'GILA (7)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'LA PAZ (12)',
#  'MOHAVE (15)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'PIMA (19)',
#  'PIMA (19)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'COCONINO (5)',
#  'GRAHAM (9)',
#  'COCHISE (3)',
#  'PINAL (21)',
#  'COCONINO (5)',
#  'YAVAPAI (25)',
#  'YAVAPAI (25)',
#  'NAVAJO (17)',
#  'YAVAPAI (25)',
#  'YAVAPAI (25)',
#  'PIMA (19)',
#  'COCONINO (5)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'YAVAPAI (25)',
#  'PINAL (21)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'YUMA (27)',
#  'PIMA (19)',
#  'PIMA (19)',
#  'GILA (7)',
#  'SANTA CRUZ (23)',
#  'PIMA (19)',
#  'PIMA (19)',
#  'NAVAJO (17)',
#  'NAVAJO (17)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'NAVAJO (17)',
#  'NAVAJO (17)',
#  'YAVAPAI (25)',
#  'MOHAVE (15)',
#  'LA PAZ (12)',
#  'MARICOPA (13)',
#  'YAVAPAI (25)',
#  'PIMA (19)',
#  'MOHAVE (15)',
#  'MOHAVE (15)',
#  'YUMA (27)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'YUMA (27)',
#  'MOHAVE (15)',
#  'YAVAPAI (25)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'COCONINO (5)',
#  'MARICOPA (13)',
#  'PIMA (19)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'APACHE (1)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'PIMA (19)',
#  'PIMA (19)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'PINAL (21)',
#  'MOHAVE (15)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'PINAL (21)',
#  'MARICOPA (13)',
#  'PINAL (21)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'APACHE (1)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'YAVAPAI (25)',
#  'MARICOPA (13)',
#  'GREENLEE (11)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'YUMA (27)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'NAVAJO (17)',
#  'PINAL (21)',
#  'MARICOPA (13)',
#  'PINAL (21)',
#  'PIMA (19)',
#  'PIMA (19)',
#  'PIMA (19)',
#  'MOHAVE (15)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'GRAHAM (9)',
#  'YUMA (27)',
#  'PIMA (19)',
#  'MARICOPA (13)',
#  'MOHAVE (15)',
#  'MOHAVE (15)',
#  'YUMA (27)',
#  'PIMA (19)',
#  'SANTA CRUZ (23)',
#  'MARICOPA (13)',
#  'MOHAVE (15)',
#  'MARICOPA (13)',
#  'COCONINO (5)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'PIMA (19)',
#  'MOHAVE (15)',
#  'YAVAPAI (25)',
#  'MOHAVE (15)',
#  'PIMA (19)',
#  'NAVAJO (17)',
#  'PIMA (19)',
#  'MARICOPA (13)',
#  'YUMA (27)',
#  'PIMA (19)',
#  'NAVAJO (17)',
#  'MARICOPA (13)',
#  'PIMA (19)',
#  'PIMA (19)',
#  'MARICOPA (13)',
#  'COCONINO (5)',
#  'GILA (7)',
#  'PIMA (19)',
#  'YUMA (27)',
#  'PIMA (19)',
#  'APACHE (1)',
#  'COCONINO (5)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'APACHE (1)',
#  'MARICOPA (13)',
#  'PIMA (19)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'APACHE (1)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'YUMA (27)',
#  'MARICOPA (13)',
#  'PIMA (19)',
#  'YAVAPAI (25)',
#  'MARICOPA (13)',
#  'YAVAPAI (25)',
#  'PINAL (21)',
#  'LA PAZ (12)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'NAVAJO (17)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'PINAL (21)',
#  'COCONINO (5)',
#  'APACHE (1)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'LA PAZ (12)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'GILA (7)',
#  'PIMA (19)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'PINAL (21)',
#  'GILA (7)',
#  'PIMA (19)',
#  'MARICOPA (13)',
#  'PIMA (19)',
#  'MARICOPA (13)',
#  'PINAL (21)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'APACHE (1)',
#  'GILA (7)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'YUMA (27)',
#  'MARICOPA (13)',
#  'PIMA (19)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'PINAL (21)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'PIMA (19)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'COCONINO (5)',
#  'NAVAJO (17)',
#  'NAVAJO (17)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'NAVAJO (17)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'YAVAPAI (25)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'PINAL (21)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'PINAL (21)',
#  'GRAHAM (9)',
#  'COCONINO (5)',
#  'PINAL (21)',
#  'GRAHAM (9)',
#  'MARICOPA (13)',
#  'PINAL (21)',
#  'MOHAVE (15)',
#  'NAVAJO (17)',
#  'PINAL (21)',
#  'PINAL (21)',
#  'NAVAJO (17)',
#  'COCHISE (3)',
#  'GRAHAM (9)',
#  'PINAL (21)',
#  'COCONINO (5)',
#  'GILA (7)',
#  'COCONINO (5)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'PINAL (21)',
#  'NAVAJO (17)',
#  'APACHE (1)',
#  'APACHE (1)',
#  'PIMA (19)',
#  'MOHAVE (15)',
#  'MARICOPA (13)',
#  'PIMA (19)',
#  'PIMA (19)',
#  'APACHE (1)',
#  'MOHAVE (15)',
#  'PIMA (19)',
#  'PIMA (19)',
#  'PINAL (21)',
#  'PIMA (19)',
#  'MOHAVE (15)',
#  'PINAL (21)',
#  'SANTA CRUZ (23)',
#  'MARICOPA (13)',
#  'GRAHAM (9)',
#  'PIMA (19)',
#  'YAVAPAI (25)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'GILA (7)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'NAVAJO (17)',
#  'PIMA (19)',
#  'YAVAPAI (25)',
#  'PINAL (21)',
#  'YAVAPAI (25)',
#  'PIMA (19)',
#  'LA PAZ (12)',
#  'LA PAZ (12)',
#  'MARICOPA (13)',
#  'PINAL (21)',
#  'PINAL (21)',
#  'MARICOPA (13)',
#  'PIMA (19)',
#  'PINAL (21)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'LA PAZ (12)',
#  'MARICOPA (13)',
#  'COCONINO (5)',
#  'YUMA (27)',
#  'MOHAVE (15)',
#  'PIMA (19)',
#  'PINAL (21)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'PIMA (19)',
#  'MOHAVE (15)',
#  'MOHAVE (15)',
#  'PIMA (19)',
#  'MARICOPA (13)',
#  'APACHE (1)',
#  'PIMA (19)',
#  'GILA (7)',
#  'MOHAVE (15)',
#  'COCONINO (5)',
#  'PIMA (19)',
#  'COCHISE (3)',
#  'COCONINO (5)',
#  'PIMA (19)',
#  'NAVAJO (17)',
#  'PIMA (19)',
#  'MARICOPA (13)',
#  'GILA (7)',
#  'MARICOPA (13)',
#  'PIMA (19)',
#  'MARICOPA (13)',
#  'PIMA (19)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'PIMA (19)',
#  'MARICOPA (13)',
#  'PIMA (19)',
#  'PIMA (19)',
#  'MARICOPA (13)',
#  'PINAL (21)',
#  'MARICOPA (13)',
#  'COCHISE (3)',
#  'MARICOPA (13)',
#  'COCONINO (5)',
#  'PIMA (19)',
#  'MARICOPA (13)',
#  'PINAL (21)',
#  'COCONINO (5)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'PIMA (19)',
#  'PINAL (21)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'GRAHAM (9)',
#  'MARICOPA (13)',
#  'MOHAVE (15)',
#  'MARICOPA (13)',
#  'PINAL (21)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'YAVAPAI (25)',
#  'MARICOPA (13)',
#  'APACHE (1)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'APACHE (1)',
#  'MOHAVE (15)',
#  'MOHAVE (15)',
#  'MARICOPA (13)',
#  'PINAL (21)',
#  'YAVAPAI (25)',
#  'MOHAVE (15)',
#  'PINAL (21)',
#  'MARICOPA (13)',
#  'PIMA (19)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'PINAL (21)',
#  'MARICOPA (13)',
#  'GILA (7)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'MOHAVE (15)',
#  'COCONINO (5)',
#  'APACHE (1)',
#  'MOHAVE (15)',
#  'YAVAPAI (25)',
#  'MARICOPA (13)',
#  'PIMA (19)',
#  'PIMA (19)',
#  'COCONINO (5)',
#  'PIMA (19)',
#  'PIMA (19)',
#  'COCONINO (5)',
#  'PIMA (19)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'YUMA (27)',
#  'COCONINO (5)',
#  'PINAL (21)',
#  'PIMA (19)',
#  'PINAL (21)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'PIMA (19)',
#  'GILA (7)',
#  'MARICOPA (13)',
#  'PIMA (19)',
#  'PINAL (21)',
#  'PINAL (21)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'YAVAPAI (25)',
#  'MARICOPA (13)',
#  'APACHE (1)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'PINAL (21)',
#  'MARICOPA (13)',
#  'APACHE (1)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'LA PAZ (12)',
#  'LA PAZ (12)',
#  'PIMA (19)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'YAVAPAI (25)',
#  'PINAL (21)',
#  'PIMA (19)',
#  'MARICOPA (13)',
#  'MOHAVE (15)',
#  'NAVAJO (17)',
#  'SANTA CRUZ (23)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'PINAL (21)',
#  'YAVAPAI (25)',
#  'MARICOPA (13)',
#  'MOHAVE (15)',
#  'YAVAPAI (25)',
#  'MARICOPA (13)',
#  'PIMA (19)',
#  'COCONINO (5)',
#  'PINAL (21)',
#  'MARICOPA (13)',
#  'YAVAPAI (25)',
#  'PIMA (19)',
#  'PIMA (19)',
#  'MARICOPA (13)',
#  'COCONINO (5)',
#  'PIMA (19)',
#  'YUMA (27)',
#  'PIMA (19)',
#  'LA PAZ (12)',
#  'PIMA (19)',
#  'PIMA (19)',
#  'MARICOPA (13)',
#  'COCHISE (3)',
#  'COCONINO (5)',
#  'PINAL (21)',
#  'SANTA CRUZ (23)',
#  'COCONINO (5)',
#  'PIMA (19)',
#  'NAVAJO (17)',
#  'PIMA (19)',
#  'MARICOPA (13)',
#  'PIMA (19)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'NAVAJO (17)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'PINAL (21)',
#  'PIMA (19)',
#  'COCONINO (5)',
#  'MARICOPA (13)',
#  'YAVAPAI (25)',
#  'COCONINO (5)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'MOHAVE (15)',
#  'YUMA (27)',
#  'PIMA (19)',
#  'SANTA CRUZ (23)',
#  'COCONINO (5)',
#  'MARICOPA (13)',
#  'COCONINO (5)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'PIMA (19)',
#  'MARICOPA (13)',
#  'PINAL (21)',
#  'YUMA (27)',
#  'APACHE (1)',
#  'MARICOPA (13)',
#  'MARICOPA (13)',
#  'COCONINO (5)',
#  'PIMA (19)',
#  'PIMA (19)',
#  ...]

# %%
AZ_dict = {
    "county_name": county,
    "Crash_date":CrashDate ,
    "Fatals": Fatals,
    "Total_vehicles":TotalVehicles
}
AZ_data =pd.DataFrame(AZ_dict)
AZ_data
# Out:
#         county_name                  Crash_date  Fatals  Total_vehicles
# 0         PIMA (19)  /Date(1388882700000-0500)/       1               2
# 1         PIMA (19)  /Date(1389095220000-0500)/       1               1
# 2     MARICOPA (13)  /Date(1389223080000-0500)/       1               1
# 3       LA PAZ (12)  /Date(1389343500000-0500)/       2               2
# 4      COCONINO (5)  /Date(1389477600000-0500)/       1               1
# ...             ...                         ...     ...             ...
# 4202  MARICOPA (13)  /Date(1523502900000-0400)/       1               2
# 4203  MARICOPA (13)  /Date(1523579400000-0400)/       1               1
# 4204  MARICOPA (13)  /Date(1523639880000-0400)/       1               3
# 4205  MARICOPA (13)  /Date(1523841120000-0400)/       1               1
# 4206  MARICOPA (13)  /Date(1524269880000-0400)/       1               2
#
# [4207 rows x 4 columns]

# %%
Maricopa_county=AZ_data.loc[AZ_data["county_name"]=="MARICOPA (13)",:]

# %%
Maricopa_county
# Out:
#         county_name                  Crash_date  Fatals  Total_vehicles
# 2     MARICOPA (13)  /Date(1389223080000-0500)/       1               1
# 6     MARICOPA (13)  /Date(1389616680000-0500)/       1               2
# 8     MARICOPA (13)  /Date(1390063140000-0500)/       1               1
# 18    MARICOPA (13)  /Date(1388628480000-0500)/       1               1
# 20    MARICOPA (13)  /Date(1390633200000-0500)/       1               1
# ...             ...                         ...     ...             ...
# 4202  MARICOPA (13)  /Date(1523502900000-0400)/       1               2
# 4203  MARICOPA (13)  /Date(1523579400000-0400)/       1               1
# 4204  MARICOPA (13)  /Date(1523639880000-0400)/       1               3
# 4205  MARICOPA (13)  /Date(1523841120000-0400)/       1               1
# 4206  MARICOPA (13)  /Date(1524269880000-0400)/       1               2
#
# [2076 rows x 4 columns]

# %%
Maricopa_county.to_csv("Maricopa County Output")
