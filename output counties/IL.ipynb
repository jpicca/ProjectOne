# %%
import json
import requests
from pprint import pprint
import pandas as pd

# %%
base_url="http://crashviewer.nhtsa.dot.gov/CrashAPI/crashes/GetCaseList?"

params = {
    'states':'17',
    'fromYear':'',
    'toYear':'',
    'minNumOfVehicles':'1',
    'maxNumOfVehicles':'10',
    'format':'json'
}

response = requests.get(base_url,params=params)

years = ['2014','2015','2016','2017','2018']

county=[]
CrashDate=[]
Fatals=[]
TotalVehicles=[]

for year in years:
    params['fromYear'] = year
    params['toYear'] = year
    
    response = requests.get(base_url,params=params).json()
   
    for county_name in response['Results'][0]:
        county.append(county_name["CountyName"])
        CrashDate.append(county_name["CrashDate"])
        Fatals.append(county_name["Fatals"])
        TotalVehicles.append(county_name["TotalVehicles"])
county
# Out:
# ['MACON (115)',
#  'BOND (5)',
#  'WILL (197)',
#  'COOK (31)',
#  'CLINTON (27)',
#  'COOK (31)',
#  'MACON (115)',
#  'PEORIA (143)',
#  'BUREAU (11)',
#  'MORGAN (137)',
#  'COOK (31)',
#  'COOK (31)',
#  'JEFFERSON (81)',
#  'MADISON (119)',
#  'HAMILTON (65)',
#  'LAWRENCE (101)',
#  'WILL (197)',
#  'DE KALB (37)',
#  'JO DAVIESS (85)',
#  'DU PAGE (43)',
#  'LA SALLE (99)',
#  'LAWRENCE (101)',
#  'LOGAN (107)',
#  'WHITE (193)',
#  'LA SALLE (99)',
#  'VERMILION (183)',
#  'GRUNDY (63)',
#  'KANKAKEE (91)',
#  'ROCK ISLAND (161)',
#  'ST CLAIR (163)',
#  'DE KALB (37)',
#  'WILL (197)',
#  'COOK (31)',
#  'PEORIA (143)',
#  'DU PAGE (43)',
#  'HANCOCK (67)',
#  'KANKAKEE (91)',
#  'DU PAGE (43)',
#  'WINNEBAGO (201)',
#  'MACON (115)',
#  'KANE (89)',
#  'BOONE (7)',
#  'SANGAMON (167)',
#  'COOK (31)',
#  'COLES (29)',
#  'WILL (197)',
#  'KANE (89)',
#  'WILL (197)',
#  'CHAMPAIGN (19)',
#  'BOONE (7)',
#  'WILL (197)',
#  'JACKSON (77)',
#  'COOK (31)',
#  'COOK (31)',
#  'MACOUPIN (117)',
#  'MADISON (119)',
#  'DU PAGE (43)',
#  'COOK (31)',
#  'ST CLAIR (163)',
#  'COOK (31)',
#  'LA SALLE (99)',
#  'WINNEBAGO (201)',
#  'COOK (31)',
#  'MONTGOMERY (135)',
#  'MCLEAN (113)',
#  'ST CLAIR (163)',
#  'WILL (197)',
#  'DE KALB (37)',
#  'MADISON (119)',
#  'MCHENRY (111)',
#  'ROCK ISLAND (161)',
#  'STARK (175)',
#  'MADISON (119)',
#  'COOK (31)',
#  'COOK (31)',
#  'CHAMPAIGN (19)',
#  'WOODFORD (203)',
#  'COOK (31)',
#  'WINNEBAGO (201)',
#  'WAYNE (191)',
#  'HANCOCK (67)',
#  'PIATT (147)',
#  'GALLATIN (59)',
#  'COOK (31)',
#  'CHAMPAIGN (19)',
#  'KENDALL (93)',
#  'LAKE (97)',
#  'KANKAKEE (91)',
#  'WINNEBAGO (201)',
#  'GRUNDY (63)',
#  'GRUNDY (63)',
#  'LAKE (97)',
#  'LAKE (97)',
#  'SANGAMON (167)',
#  'COOK (31)',
#  'COLES (29)',
#  'COOK (31)',
#  'COOK (31)',
#  'COOK (31)',
#  'COOK (31)',
#  'COLES (29)',
#  'CALHOUN (13)',
#  'POPE (151)',
#  'COOK (31)',
#  'COOK (31)',
#  'COOK (31)',
#  'CHAMPAIGN (19)',
#  'KANKAKEE (91)',
#  'COOK (31)',
#  'COOK (31)',
#  'COOK (31)',
#  'COOK (31)',
#  'COOK (31)',
#  'MCLEAN (113)',
#  'LIVINGSTON (105)',
#  'MADISON (119)',
#  'ST CLAIR (163)',
#  'COOK (31)',
#  'WILL (197)',
#  'MADISON (119)',
#  'JEFFERSON (81)',
#  'WINNEBAGO (201)',
#  'SANGAMON (167)',
#  'KENDALL (93)',
#  'COOK (31)',
#  'PERRY (145)',
#  'COOK (31)',
#  'LIVINGSTON (105)',
#  'WILL (197)',
#  'MCLEAN (113)',
#  'COOK (31)',
#  'LAKE (97)',
#  'COOK (31)',
#  'MCHENRY (111)',
#  'DE KALB (37)',
#  'KANE (89)',
#  'COOK (31)',
#  'COOK (31)',
#  'ST CLAIR (163)',
#  'COOK (31)',
#  'ROCK ISLAND (161)',
#  'DU PAGE (43)',
#  'SCHUYLER (169)',
#  'LAWRENCE (101)',
#  'MCHENRY (111)',
#  'VERMILION (183)',
#  'WASHINGTON (189)',
#  'MERCER (131)',
#  'WILL (197)',
#  'MENARD (129)',
#  'ST CLAIR (163)',
#  'COOK (31)',
#  'KANKAKEE (91)',
#  'KENDALL (93)',
#  'PULASKI (153)',
#  'ST CLAIR (163)',
#  'COOK (31)',
#  'MACON (115)',
#  'HENRY (73)',
#  'IROQUOIS (75)',
#  'COOK (31)',
#  'JO DAVIESS (85)',
#  'ST CLAIR (163)',
#  'CLARK (23)',
#  'COOK (31)',
#  'BOND (5)',
#  'MARSHALL (123)',
#  'OGLE (141)',
#  'KANE (89)',
#  'MACON (115)',
#  'SANGAMON (167)',
#  'CHAMPAIGN (19)',
#  'FAYETTE (51)',
#  'KANKAKEE (91)',
#  'COOK (31)',
#  'COOK (31)',
#  'PEORIA (143)',
#  'COLES (29)',
#  'COOK (31)',
#  'HANCOCK (67)',
#  'JASPER (79)',
#  'MCHENRY (111)',
#  'WILL (197)',
#  'LOGAN (107)',
#  'MADISON (119)',
#  'KANKAKEE (91)',
#  'CLINTON (27)',
#  'COOK (31)',
#  'COOK (31)',
#  'COOK (31)',
#  'COOK (31)',
#  'COOK (31)',
#  'KANE (89)',
#  'KANKAKEE (91)',
#  'MCHENRY (111)',
#  'SANGAMON (167)',
#  'WILL (197)',
#  'MADISON (119)',
#  'ST CLAIR (163)',
#  'MCHENRY (111)',
#  'SANGAMON (167)',
#  'MADISON (119)',
#  'PERRY (145)',
#  'COOK (31)',
#  'COOK (31)',
#  'WILL (197)',
#  'WILL (197)',
#  'JACKSON (77)',
#  'MADISON (119)',
#  'CRAWFORD (33)',
#  'LAWRENCE (101)',
#  'COOK (31)',
#  'JERSEY (83)',
#  'COOK (31)',
#  'CHAMPAIGN (19)',
#  'ST CLAIR (163)',
#  'CLINTON (27)',
#  'DE KALB (37)',
#  'LOGAN (107)',
#  'MADISON (119)',
#  'CHAMPAIGN (19)',
#  'JO DAVIESS (85)',
#  'WOODFORD (203)',
#  'DE WITT (39)',
#  'ST CLAIR (163)',
#  'COOK (31)',
#  'EFFINGHAM (49)',
#  'JASPER (79)',
#  'WILL (197)',
#  'MCHENRY (111)',
#  'CHAMPAIGN (19)',
#  'COOK (31)',
#  'MADISON (119)',
#  'STEPHENSON (177)',
#  'MCLEAN (113)',
#  'CLINTON (27)',
#  'COOK (31)',
#  'WINNEBAGO (201)',
#  'RANDOLPH (157)',
#  'DU PAGE (43)',
#  'COOK (31)',
#  'WILL (197)',
#  'WILL (197)',
#  'KANE (89)',
#  'LEE (103)',
#  'MONTGOMERY (135)',
#  'PEORIA (143)',
#  'LAWRENCE (101)',
#  'MADISON (119)',
#  'DU PAGE (43)',
#  'MACON (115)',
#  'MACON (115)',
#  'WHITESIDE (195)',
#  'ST CLAIR (163)',
#  'COOK (31)',
#  'TAZEWELL (179)',
#  'MCLEAN (113)',
#  'MCHENRY (111)',
#  'COOK (31)',
#  'CHRISTIAN (21)',
#  'LAKE (97)',
#  'COOK (31)',
#  'DU PAGE (43)',
#  'COOK (31)',
#  'COOK (31)',
#  'LAKE (97)',
#  'JERSEY (83)',
#  'STEPHENSON (177)',
#  'LEE (103)',
#  'KANE (89)',
#  'LAKE (97)',
#  'KANKAKEE (91)',
#  'PERRY (145)',
#  'COOK (31)',
#  'STARK (175)',
#  'WILL (197)',
#  'MCLEAN (113)',
#  'MONTGOMERY (135)',
#  'JACKSON (77)',
#  'RANDOLPH (157)',
#  'GRUNDY (63)',
#  'ADAMS (1)',
#  'FRANKLIN (55)',
#  'WILL (197)',
#  'CLINTON (27)',
#  'KNOX (95)',
#  'KNOX (95)',
#  'LA SALLE (99)',
#  'MCHENRY (111)',
#  'LA SALLE (99)',
#  'KNOX (95)',
#  'COOK (31)',
#  'WASHINGTON (189)',
#  'MCDONOUGH (109)',
#  'JO DAVIESS (85)',
#  'PEORIA (143)',
#  'MADISON (119)',
#  'OGLE (141)',
#  'CLAY (25)',
#  'WILL (197)',
#  'MCLEAN (113)',
#  'LAKE (97)',
#  'MADISON (119)',
#  'COOK (31)',
#  'MADISON (119)',
#  'COOK (31)',
#  'CHAMPAIGN (19)',
#  'WILL (197)',
#  'COOK (31)',
#  'ST CLAIR (163)',
#  'BOND (5)',
#  'HARDIN (69)',
#  'LEE (103)',
#  'FRANKLIN (55)',
#  'FRANKLIN (55)',
#  'COOK (31)',
#  'COOK (31)',
#  'PEORIA (143)',
#  'COOK (31)',
#  'COOK (31)',
#  'COOK (31)',
#  'WILL (197)',
#  'DOUGLAS (41)',
#  'PEORIA (143)',
#  'WINNEBAGO (201)',
#  'MADISON (119)',
#  'SALINE (165)',
#  'COOK (31)',
#  'PIKE (149)',
#  'LAKE (97)',
#  'JACKSON (77)',
#  'COOK (31)',
#  'DE KALB (37)',
#  'FAYETTE (51)',
#  'MCHENRY (111)',
#  'FRANKLIN (55)',
#  'SANGAMON (167)',
#  'LA SALLE (99)',
#  'CARROLL (15)',
#  'BOONE (7)',
#  'COOK (31)',
#  'WILL (197)',
#  'MADISON (119)',
#  'WINNEBAGO (201)',
#  'LA SALLE (99)',
#  'GRUNDY (63)',
#  'PIKE (149)',
#  'COOK (31)',
#  'COOK (31)',
#  'ROCK ISLAND (161)',
#  'WILL (197)',
#  'WINNEBAGO (201)',
#  'COOK (31)',
#  'ADAMS (1)',
#  'COOK (31)',
#  'COOK (31)',
#  'JEFFERSON (81)',
#  'WILL (197)',
#  'WILL (197)',
#  'COOK (31)',
#  'COOK (31)',
#  'COOK (31)',
#  'COOK (31)',
#  'COOK (31)',
#  'COOK (31)',
#  'COOK (31)',
#  'WINNEBAGO (201)',
#  'COOK (31)',
#  'COLES (29)',
#  'MONROE (133)',
#  'COOK (31)',
#  'COOK (31)',
#  'CASS (17)',
#  'COOK (31)',
#  'COOK (31)',
#  'COOK (31)',
#  'COOK (31)',
#  'COOK (31)',
#  'PEORIA (143)',
#  'COOK (31)',
#  'COOK (31)',
#  'COOK (31)',
#  'COOK (31)',
#  'COOK (31)',
#  'COOK (31)',
#  'COOK (31)',
#  'COOK (31)',
#  'WINNEBAGO (201)',
#  'ROCK ISLAND (161)',
#  'COOK (31)',
#  'DE KALB (37)',
#  'ST CLAIR (163)',
#  'COOK (31)',
#  'FRANKLIN (55)',
#  'WILL (197)',
#  'IROQUOIS (75)',
#  'KANE (89)',
#  'MCHENRY (111)',
#  'STEPHENSON (177)',
#  'MACON (115)',
#  'WILLIAMSON (199)',
#  'SALINE (165)',
#  'COOK (31)',
#  'CLINTON (27)',
#  'COOK (31)',
#  'COOK (31)',
#  'COOK (31)',
#  'WASHINGTON (189)',
#  'TAZEWELL (179)',
#  'LAKE (97)',
#  'IROQUOIS (75)',
#  'BUREAU (11)',
#  'MADISON (119)',
#  'LAKE (97)',
#  'COOK (31)',
#  'LAKE (97)',
#  'SANGAMON (167)',
#  'MADISON (119)',
#  'WASHINGTON (189)',
#  'MONROE (133)',
#  'FRANKLIN (55)',
#  'JERSEY (83)',
#  'SANGAMON (167)',
#  'COOK (31)',
#  'COOK (31)',
#  'LA SALLE (99)',
#  'MADISON (119)',
#  'ST CLAIR (163)',
#  'KANKAKEE (91)',
#  'SANGAMON (167)',
#  'SALINE (165)',
#  'WILL (197)',
#  'WILL (197)',
#  'KANE (89)',
#  'MORGAN (137)',
#  'WINNEBAGO (201)',
#  'LEE (103)',
#  'MADISON (119)',
#  'LA SALLE (99)',
#  'WILL (197)',
#  'PEORIA (143)',
#  'COOK (31)',
#  'MACON (115)',
#  'CHRISTIAN (21)',
#  'MCHENRY (111)',
#  'TAZEWELL (179)',
#  'PEORIA (143)',
#  'PEORIA (143)',
#  'WINNEBAGO (201)',
#  'VERMILION (183)',
#  'RANDOLPH (157)',
#  'KENDALL (93)',
#  'WINNEBAGO (201)',
#  'COOK (31)',
#  'LOGAN (107)',
#  'COOK (31)',
#  'WILL (197)',
#  'KENDALL (93)',
#  'BUREAU (11)',
#  'PIATT (147)',
#  'ADAMS (1)',
#  'WILL (197)',
#  'DU PAGE (43)',
#  'BOONE (7)',
#  'KANE (89)',
#  'COOK (31)',
#  'WINNEBAGO (201)',
#  'WILL (197)',
#  'LAKE (97)',
#  'OGLE (141)',
#  'ST CLAIR (163)',
#  'HENRY (73)',
#  'COOK (31)',
#  'WOODFORD (203)',
#  'MADISON (119)',
#  'MACOUPIN (117)',
#  'MADISON (119)',
#  'COOK (31)',
#  'COOK (31)',
#  'WINNEBAGO (201)',
#  'WILL (197)',
#  'FORD (53)',
#  'LEE (103)',
#  'COOK (31)',
#  'MOULTRIE (139)',
#  'COOK (31)',
#  'ST CLAIR (163)',
#  'KANE (89)',
#  'GRUNDY (63)',
#  'COOK (31)',
#  'LIVINGSTON (105)',
#  'COOK (31)',
#  'LAKE (97)',
#  'MCHENRY (111)',
#  'FAYETTE (51)',
#  'ROCK ISLAND (161)',
#  'SANGAMON (167)',
#  'LA SALLE (99)',
#  'WINNEBAGO (201)',
#  'COOK (31)',
#  'FAYETTE (51)',
#  'TAZEWELL (179)',
#  'COOK (31)',
#  'WILL (197)',
#  'COOK (31)',
#  'DU PAGE (43)',
#  'LAKE (97)',
#  'DU PAGE (43)',
#  'JACKSON (77)',
#  'SALINE (165)',
#  'COOK (31)',
#  'CHAMPAIGN (19)',
#  'WINNEBAGO (201)',
#  'SANGAMON (167)',
#  'MARSHALL (123)',
#  'LAKE (97)',
#  'LAKE (97)',
#  'COOK (31)',
#  'MADISON (119)',
#  'DE KALB (37)',
#  'COOK (31)',
#  'COLES (29)',
#  'KANE (89)',
#  'COOK (31)',
#  'MCLEAN (113)',
#  'BOND (5)',
#  'WASHINGTON (189)',
#  'WILL (197)',
#  'WILL (197)',
#  'KANKAKEE (91)',
#  'MCHENRY (111)',
#  'LEE (103)',
#  'COOK (31)',
#  'MADISON (119)',
#  'LA SALLE (99)',
#  'DE KALB (37)',
#  'SANGAMON (167)',
#  'COOK (31)',
#  'COOK (31)',
#  'BOND (5)',
#  'MADISON (119)',
#  'RANDOLPH (157)',
#  'WILL (197)',
#  'COOK (31)',
#  'RANDOLPH (157)',
#  'WINNEBAGO (201)',
#  'MCLEAN (113)',
#  'CLAY (25)',
#  'WINNEBAGO (201)',
#  'COOK (31)',
#  'COOK (31)',
#  'MORGAN (137)',
#  'MCHENRY (111)',
#  'UNION (181)',
#  'ST CLAIR (163)',
#  'MCDONOUGH (109)',
#  'MONTGOMERY (135)',
#  'WAYNE (191)',
#  'LA SALLE (99)',
#  'KANE (89)',
#  'WILLIAMSON (199)',
#  'COOK (31)',
#  'COOK (31)',
#  'CHRISTIAN (21)',
#  'GRUNDY (63)',
#  'SANGAMON (167)',
#  'OGLE (141)',
#  'MADISON (119)',
#  'BOONE (7)',
#  'COOK (31)',
#  'DU PAGE (43)',
#  'FORD (53)',
#  'COOK (31)',
#  'WILL (197)',
#  'WILLIAMSON (199)',
#  'COOK (31)',
#  'COOK (31)',
#  'LAKE (97)',
#  'COOK (31)',
#  'WILL (197)',
#  'KANE (89)',
#  'MCHENRY (111)',
#  'VERMILION (183)',
#  'OGLE (141)',
#  'LA SALLE (99)',
#  'COOK (31)',
#  'KANE (89)',
#  'WILL (197)',
#  'CHRISTIAN (21)',
#  'FAYETTE (51)',
#  'BOONE (7)',
#  'MCLEAN (113)',
#  'COOK (31)',
#  'MACON (115)',
#  'PEORIA (143)',
#  'MADISON (119)',
#  'LEE (103)',
#  'SANGAMON (167)',
#  'KANE (89)',
#  'COOK (31)',
#  'VERMILION (183)',
#  'COLES (29)',
#  'JO DAVIESS (85)',
#  'EDGAR (45)',
#  'COOK (31)',
#  'PEORIA (143)',
#  'COOK (31)',
#  'WILL (197)',
#  'PERRY (145)',
#  'KANE (89)',
#  'COOK (31)',
#  'LAKE (97)',
#  'LOGAN (107)',
#  'PEORIA (143)',
#  'DOUGLAS (41)',
#  'MENARD (129)',
#  'PEORIA (143)',
#  'ROCK ISLAND (161)',
#  'COOK (31)',
#  'DU PAGE (43)',
#  'SALINE (165)',
#  'MADISON (119)',
#  'WARREN (187)',
#  'ST CLAIR (163)',
#  'FULTON (57)',
#  'COOK (31)',
#  'EFFINGHAM (49)',
#  'KANE (89)',
#  'MORGAN (137)',
#  'CHAMPAIGN (19)',
#  'SANGAMON (167)',
#  'ADAMS (1)',
#  'ST CLAIR (163)',
#  'TAZEWELL (179)',
#  'TAZEWELL (179)',
#  'WINNEBAGO (201)',
#  'WHITESIDE (195)',
#  'COOK (31)',
#  'MCHENRY (111)',
#  'VERMILION (183)',
#  'EFFINGHAM (49)',
#  'HARDIN (69)',
#  'EFFINGHAM (49)',
#  'COOK (31)',
#  'COOK (31)',
#  'COOK (31)',
#  'COOK (31)',
#  'COOK (31)',
#  'COOK (31)',
#  'COOK (31)',
#  'COOK (31)',
#  'COOK (31)',
#  'WILL (197)',
#  'COOK (31)',
#  'WILL (197)',
#  'MCDONOUGH (109)',
#  'LAKE (97)',
#  'COOK (31)',
#  'DU PAGE (43)',
#  'TAZEWELL (179)',
#  'CLARK (23)',
#  'HENDERSON (71)',
#  'KANKAKEE (91)',
#  'CLARK (23)',
#  'FAYETTE (51)',
#  'COOK (31)',
#  'COOK (31)',
#  'LAKE (97)',
#  'ROCK ISLAND (161)',
#  'MCHENRY (111)',
#  'PEORIA (143)',
#  'TAZEWELL (179)',
#  'JACKSON (77)',
#  'WILL (197)',
#  'STARK (175)',
#  'DOUGLAS (41)',
#  'KANE (89)',
#  'ST CLAIR (163)',
#  'DU PAGE (43)',
#  'MARSHALL (123)',
#  'COOK (31)',
#  'MONTGOMERY (135)',
#  'ST CLAIR (163)',
#  'COOK (31)',
#  'ROCK ISLAND (161)',
#  'ST CLAIR (163)',
#  'WILL (197)',
#  'LA SALLE (99)',
#  'LAKE (97)',
#  'MADISON (119)',
#  'LA SALLE (99)',
#  'BUREAU (11)',
#  'HAMILTON (65)',
#  'LA SALLE (99)',
#  'JACKSON (77)',
#  'WILL (197)',
#  'COOK (31)',
#  'COOK (31)',
#  'MONTGOMERY (135)',
#  'DU PAGE (43)',
#  'COOK (31)',
#  'CLINTON (27)',
#  'MONTGOMERY (135)',
#  'COOK (31)',
#  'DU PAGE (43)',
#  'MARION (121)',
#  'JERSEY (83)',
#  'COOK (31)',
#  'LAKE (97)',
#  'FORD (53)',
#  'ST CLAIR (163)',
#  'COLES (29)',
#  'HENDERSON (71)',
#  'COOK (31)',
#  'TAZEWELL (179)',
#  'MCLEAN (113)',
#  'DU PAGE (43)',
#  'LA SALLE (99)',
#  'SANGAMON (167)',
#  'IROQUOIS (75)',
#  'CHAMPAIGN (19)',
#  'COOK (31)',
#  'COOK (31)',
#  'TAZEWELL (179)',
#  'MACON (115)',
#  'MCLEAN (113)',
#  'WILL (197)',
#  'WILL (197)',
#  'PEORIA (143)',
#  'KENDALL (93)',
#  'RICHLAND (159)',
#  'COOK (31)',
#  'COOK (31)',
#  'MADISON (119)',
#  'WHITE (193)',
#  'CARROLL (15)',
#  'WINNEBAGO (201)',
#  'COOK (31)',
#  'TAZEWELL (179)',
#  'JEFFERSON (81)',
#  'JEFFERSON (81)',
#  'KANE (89)',
#  'SCHUYLER (169)',
#  'COOK (31)',
#  'WILL (197)',
#  'MACON (115)',
#  'DU PAGE (43)',
#  'WILL (197)',
#  'WILL (197)',
#  'MARSHALL (123)',
#  'WILL (197)',
#  'DU PAGE (43)',
#  'EFFINGHAM (49)',
#  'CHAMPAIGN (19)',
#  'DU PAGE (43)',
#  'WILL (197)',
#  'PEORIA (143)',
#  'EFFINGHAM (49)',
#  'DU PAGE (43)',
#  'COOK (31)',
#  'STEPHENSON (177)',
#  'WILLIAMSON (199)',
#  'PEORIA (143)',
#  'WILLIAMSON (199)',
#  'CHAMPAIGN (19)',
#  'EFFINGHAM (49)',
#  'ST CLAIR (163)',
#  'MASSAC (127)',
#  'COOK (31)',
#  'MACON (115)',
#  'ST CLAIR (163)',
#  'COOK (31)',
#  'UNION (181)',
#  'ST CLAIR (163)',
#  'LAKE (97)',
#  'DE KALB (37)',
#  'HENRY (73)',
#  'RANDOLPH (157)',
#  'LA SALLE (99)',
#  'ST CLAIR (163)',
#  'SANGAMON (167)',
#  'LA SALLE (99)',
#  'HENRY (73)',
#  'KANKAKEE (91)',
#  'COOK (31)',
#  'COOK (31)',
#  'COOK (31)',
#  'WILLIAMSON (199)',
#  'COOK (31)',
#  'COOK (31)',
#  'COOK (31)',
#  'MCLEAN (113)',
#  'LIVINGSTON (105)',
#  'COOK (31)',
#  'DU PAGE (43)',
#  'KNOX (95)',
#  'LAKE (97)',
#  'LAKE (97)',
#  'KENDALL (93)',
#  'KENDALL (93)',
#  'JEFFERSON (81)',
#  'FRANKLIN (55)',
#  'WILLIAMSON (199)',
#  'SHELBY (173)',
#  'COOK (31)',
#  'COOK (31)',
#  'COOK (31)',
#  'COOK (31)',
#  'MCLEAN (113)',
#  'COOK (31)',
#  'RANDOLPH (157)',
#  'COOK (31)',
#  'GREENE (61)',
#  'JO DAVIESS (85)',
#  'CHAMPAIGN (19)',
#  'MONROE (133)',
#  'LAKE (97)',
#  'WASHINGTON (189)',
#  'ST CLAIR (163)',
#  'OGLE (141)',
#  'FAYETTE (51)',
#  'COOK (31)',
#  'COOK (31)',
#  'MCLEAN (113)',
#  'KANE (89)',
#  'LAKE (97)',
#  'COOK (31)',
#  'COOK (31)',
#  'COOK (31)',
#  'COOK (31)',
#  'COOK (31)',
#  'COOK (31)',
#  'COOK (31)',
#  'COOK (31)',
#  'COOK (31)',
#  'VERMILION (183)',
#  'COOK (31)',
#  'COOK (31)',
#  'COOK (31)',
#  'KENDALL (93)',
#  'LAKE (97)',
#  'LAKE (97)',
#  'COOK (31)',
#  'COOK (31)',
#  'KANKAKEE (91)',
#  'WINNEBAGO (201)',
#  'WINNEBAGO (201)',
#  'COOK (31)',
#  'MCLEAN (113)',
#  'CLINTON (27)',
#  'WASHINGTON (189)',
#  'MONROE (133)',
#  'VERMILION (183)',
#  'COOK (31)',
#  'MACON (115)',
#  'COOK (31)',
#  'WHITESIDE (195)',
#  'ROCK ISLAND (161)',
#  'CHRISTIAN (21)',
#  'MACON (115)',
#  'ST CLAIR (163)',
#  'JOHNSON (87)',
#  'LAKE (97)',
#  'WILL (197)',
#  'KANE (89)',
#  'SANGAMON (167)',
#  'MCLEAN (113)',
#  'LA SALLE (99)',
#  'KANE (89)',
#  'LA SALLE (99)',
#  'TAZEWELL (179)',
#  'LIVINGSTON (105)',
#  'COOK (31)',
#  'KNOX (95)',
#  'WILL (197)',
#  'LAWRENCE (101)',
#  'MADISON (119)',
#  'CHRISTIAN (21)',
#  'MACOUPIN (117)',
#  'CLINTON (27)',
#  'PEORIA (143)',
#  'KANKAKEE (91)',
#  'WINNEBAGO (201)',
#  'ROCK ISLAND (161)',
#  'CHAMPAIGN (19)',
#  'COOK (31)',
#  'MACON (115)',
#  'KANE (89)',
#  'ROCK ISLAND (161)',
#  'KANKAKEE (91)',
#  'MCLEAN (113)',
#  'JACKSON (77)',
#  'LAKE (97)',
#  'KANE (89)',
#  'PEORIA (143)',
#  'LAKE (97)',
#  'COOK (31)',
#  'COOK (31)',
#  'CHAMPAIGN (19)',
#  'WOODFORD (203)',
#  'WILL (197)',
#  'KANE (89)',
#  'MCHENRY (111)',
#  'MCHENRY (111)',
#  'KANKAKEE (91)',
#  'COOK (31)',
#  'WASHINGTON (189)',
#  'ADAMS (1)',
#  'WILL (197)',
#  'KANE (89)',
#  'COOK (31)',
#  'WHITESIDE (195)',
#  'COOK (31)',
#  'COOK (31)',
#  'MCLEAN (113)',
#  'MCLEAN (113)',
#  'RICHLAND (159)',
#  'PULASKI (153)',
#  'WILL (197)',
#  'MACON (115)',
#  'HANCOCK (67)',
#  'TAZEWELL (179)',
#  'CASS (17)',
#  'GRUNDY (63)',
#  'MONROE (133)',
#  'DE KALB (37)',
#  'MADISON (119)',
#  'COOK (31)',
#  'JACKSON (77)',
#  'DE KALB (37)',
#  'DE KALB (37)',
#  'WHITESIDE (195)',
#  'DE KALB (37)',
#  'KANE (89)',
#  'TAZEWELL (179)',
#  'LOGAN (107)',
#  'BUREAU (11)',
#  'CASS (17)',
#  'COOK (31)',
#  'COOK (31)',
#  'PEORIA (143)',
#  'LAKE (97)',
#  'WHITESIDE (195)',
#  'JO DAVIESS (85)',
#  'JO DAVIESS (85)',
#  'WILL (197)',
#  'MCLEAN (113)',
#  'KNOX (95)',
#  'OGLE (141)',
#  'FRANKLIN (55)',
#  'COOK (31)',
#  'COOK (31)',
#  'MACON (115)',
#  'WILLIAMSON (199)',
#  'MADISON (119)',
#  'COOK (31)',
#  'KNOX (95)',
#  'VERMILION (183)',
#  'ST CLAIR (163)',
#  'KANE (89)',
#  'PIKE (149)',
#  'WILL (197)',
#  'TAZEWELL (179)',
#  'WILLIAMSON (199)',
#  'MACOUPIN (117)',
#  'COOK (31)',
#  'MCLEAN (113)',
#  'SALINE (165)',
#  'WILL (197)',
#  'WINNEBAGO (201)',
#  'HENDERSON (71)',
#  'MADISON (119)',
#  'MARION (121)',
#  'TAZEWELL (179)',
#  'GREENE (61)',
#  'KANE (89)',
#  'WINNEBAGO (201)',
#  'MADISON (119)',
#  'DU PAGE (43)',
#  'DU PAGE (43)',
#  'WILLIAMSON (199)',
#  'FRANKLIN (55)',
#  'MADISON (119)',
#  'CHAMPAIGN (19)',
#  'MOULTRIE (139)',
#  'DU PAGE (43)',
#  'DU PAGE (43)',
#  'WILL (197)',
#  'WILL (197)',
#  'COOK (31)',
#  'HENRY (73)',
#  'COOK (31)',
#  'COOK (31)',
#  'COOK (31)',
#  'WILL (197)',
#  'VERMILION (183)',
#  'LA SALLE (99)',
#  'COOK (31)',
#  'ST CLAIR (163)',
#  'WILLIAMSON (199)',
#  ...]

# %%
len(county)
# Out:
# 4702

# %%
IL_dict = {
    "county_name": county,
    "Crash_date":CrashDate ,
    "Fatals": Fatals,
    "Total_vehicles":TotalVehicles
}
IL_data =pd.DataFrame(IL_dict)
IL_data
# Out:
#           county_name                  Crash_date  Fatals  Total_vehicles
# 0         MACON (115)  /Date(1388627820000-0500)/       1               1
# 1            BOND (5)  /Date(1388562840000-0500)/       1               1
# 2          WILL (197)  /Date(1388599500000-0500)/       1               2
# 3           COOK (31)  /Date(1389060420000-0500)/       1               2
# 4        CLINTON (27)  /Date(1389509340000-0500)/       2               1
# ...               ...                         ...     ...             ...
# 4697        COOK (31)  /Date(1539994440000-0400)/       1               1
# 4698   ST CLAIR (163)  /Date(1544406540000-0500)/       1               3
# 4699  VERMILION (183)  /Date(1534950000000-0400)/       1               2
# 4700        LAKE (97)  /Date(1544238300000-0500)/       1               2
# 4701        COOK (31)  /Date(1541381880000-0500)/       1               9
#
# [4702 rows x 4 columns]

# %%
cook_county=IL_data.loc[IL_data["county_name"]=="COOK (31)" ,:]

# %%
cook_county
# Out:
#      county_name                  Crash_date  Fatals  Total_vehicles
# 3      COOK (31)  /Date(1389060420000-0500)/       1               2
# 5      COOK (31)  /Date(1389515640000-0500)/       2               3
# 10     COOK (31)  /Date(1389715800000-0500)/       1               1
# 11     COOK (31)  /Date(1389975600000-0500)/       1               1
# 32     COOK (31)  /Date(1391063820000-0500)/       1               2
# ...          ...                         ...     ...             ...
# 4692   COOK (31)  /Date(1542261840000-0500)/       2               2
# 4694   COOK (31)  /Date(1538435220000-0400)/       3               4
# 4695   COOK (31)  /Date(1540883100000-0400)/       1               1
# 4697   COOK (31)  /Date(1539994440000-0400)/       1               1
# 4701   COOK (31)  /Date(1541381880000-0500)/       1               9
#
# [1194 rows x 4 columns]

# %%
cook_county.to_csv("Cook County Output")
