# %%
import json
import requests
from pprint import pprint
import pandas as pd

# %%
base_url="http://crashviewer.nhtsa.dot.gov/CrashAPI/crashes/GetCaseList?"

params = {
    'states':'42',
    'fromYear':'',
    'toYear':'',
    'minNumOfVehicles':'1',
    'maxNumOfVehicles':'10',
    'format':'json'
}

response = requests.get(base_url,params=params)

years = ['2014','2015','2016','2017','2018']

county=[]
CrashDate=[]
Fatals=[]
TotalVehicles=[]

for year in years:
    params['fromYear'] = year
    params['toYear'] = year
    
    response = requests.get(base_url,params=params).json()
   
    for county_name in response['Results'][0]:
        county.append(county_name["CountyName"])
        CrashDate.append(county_name["CrashDate"])
        Fatals.append(county_name["Fatals"])
        TotalVehicles.append(county_name["TotalVehicles"])
county
# Out:
# ['SCHUYLKILL (107)',
#  'CAMBRIA (21)',
#  'SCHUYLKILL (107)',
#  'PERRY (99)',
#  'WYOMING (131)',
#  'HUNTINGDON (61)',
#  'ALLEGHENY (3)',
#  'SCHUYLKILL (107)',
#  'LANCASTER (71)',
#  'WESTMORELAND (129)',
#  'LAWRENCE (73)',
#  'WASHINGTON (125)',
#  'HUNTINGDON (61)',
#  'WASHINGTON (125)',
#  'MCKEAN (83)',
#  'MONTGOMERY (91)',
#  'SUSQUEHANNA (115)',
#  'BERKS (11)',
#  'BERKS (11)',
#  'BUCKS (17)',
#  'DELAWARE (45)',
#  'BUCKS (17)',
#  'WESTMORELAND (129)',
#  'SUSQUEHANNA (115)',
#  'BUCKS (17)',
#  'BERKS (11)',
#  'SULLIVAN (113)',
#  'ERIE (49)',
#  'BERKS (11)',
#  'YORK (133)',
#  'PHILADELPHIA (101)',
#  'PHILADELPHIA (101)',
#  'YORK (133)',
#  'MONTGOMERY (91)',
#  'ALLEGHENY (3)',
#  'LAWRENCE (73)',
#  'CHESTER (29)',
#  'TIOGA (117)',
#  'BUCKS (17)',
#  'BUTLER (19)',
#  'MERCER (85)',
#  'WESTMORELAND (129)',
#  'ALLEGHENY (3)',
#  'SCHUYLKILL (107)',
#  'PERRY (99)',
#  'LYCOMING (81)',
#  'JUNIATA (67)',
#  'NORTHAMPTON (95)',
#  'YORK (133)',
#  'BERKS (11)',
#  'ERIE (49)',
#  'DELAWARE (45)',
#  'NORTHAMPTON (95)',
#  'MONTGOMERY (91)',
#  'YORK (133)',
#  'BERKS (11)',
#  'CUMBERLAND (41)',
#  'ERIE (49)',
#  'DELAWARE (45)',
#  'NORTHAMPTON (95)',
#  'ALLEGHENY (3)',
#  'LUZERNE (79)',
#  'NORTHAMPTON (95)',
#  'PHILADELPHIA (101)',
#  'DELAWARE (45)',
#  'MERCER (85)',
#  'DELAWARE (45)',
#  'LAWRENCE (73)',
#  'WESTMORELAND (129)',
#  'BEDFORD (9)',
#  'PHILADELPHIA (101)',
#  'LEBANON (75)',
#  'COLUMBIA (37)',
#  'PHILADELPHIA (101)',
#  'ERIE (49)',
#  'PHILADELPHIA (101)',
#  'ALLEGHENY (3)',
#  'SNYDER (109)',
#  'YORK (133)',
#  'LEHIGH (77)',
#  'ALLEGHENY (3)',
#  'BEAVER (7)',
#  'CHESTER (29)',
#  'LANCASTER (71)',
#  'CLINTON (35)',
#  'ALLEGHENY (3)',
#  'CHESTER (29)',
#  'ADAMS (1)',
#  'BUCKS (17)',
#  'LUZERNE (79)',
#  'LUZERNE (79)',
#  'CUMBERLAND (41)',
#  'WASHINGTON (125)',
#  'JUNIATA (67)',
#  'PHILADELPHIA (101)',
#  'LANCASTER (71)',
#  'DELAWARE (45)',
#  'BRADFORD (15)',
#  'BLAIR (13)',
#  'LEHIGH (77)',
#  'BUTLER (19)',
#  'CENTRE (27)',
#  'WASHINGTON (125)',
#  'BERKS (11)',
#  'LACKAWANNA (69)',
#  'WESTMORELAND (129)',
#  'ALLEGHENY (3)',
#  'WYOMING (131)',
#  'LEHIGH (77)',
#  'WESTMORELAND (129)',
#  'LEHIGH (77)',
#  'SUSQUEHANNA (115)',
#  'ALLEGHENY (3)',
#  'NORTHAMPTON (95)',
#  'MERCER (85)',
#  'BERKS (11)',
#  'PHILADELPHIA (101)',
#  'YORK (133)',
#  'BUTLER (19)',
#  'DELAWARE (45)',
#  'ALLEGHENY (3)',
#  'LANCASTER (71)',
#  'YORK (133)',
#  'LANCASTER (71)',
#  'COLUMBIA (37)',
#  'BERKS (11)',
#  'LYCOMING (81)',
#  'CUMBERLAND (41)',
#  'SNYDER (109)',
#  'CUMBERLAND (41)',
#  'WESTMORELAND (129)',
#  'LUZERNE (79)',
#  'GREENE (59)',
#  'YORK (133)',
#  'CLINTON (35)',
#  'NORTHAMPTON (95)',
#  'WASHINGTON (125)',
#  'LEHIGH (77)',
#  'CUMBERLAND (41)',
#  'LANCASTER (71)',
#  'CLINTON (35)',
#  'ERIE (49)',
#  'BUCKS (17)',
#  'INDIANA (63)',
#  'BUTLER (19)',
#  'SCHUYLKILL (107)',
#  'PHILADELPHIA (101)',
#  'INDIANA (63)',
#  'PIKE (103)',
#  'ARMSTRONG (5)',
#  'LEBANON (75)',
#  'PHILADELPHIA (101)',
#  'BERKS (11)',
#  'ADAMS (1)',
#  'SCHUYLKILL (107)',
#  'ERIE (49)',
#  'CLEARFIELD (33)',
#  'MCKEAN (83)',
#  'WESTMORELAND (129)',
#  'UNION (119)',
#  'PHILADELPHIA (101)',
#  'WYOMING (131)',
#  'LUZERNE (79)',
#  'LYCOMING (81)',
#  'UNION (119)',
#  'MERCER (85)',
#  'MONTGOMERY (91)',
#  'LAWRENCE (73)',
#  'LEHIGH (77)',
#  'BEDFORD (9)',
#  'PHILADELPHIA (101)',
#  'ALLEGHENY (3)',
#  'ERIE (49)',
#  'DELAWARE (45)',
#  'CARBON (25)',
#  'CUMBERLAND (41)',
#  'ALLEGHENY (3)',
#  'WASHINGTON (125)',
#  'CLEARFIELD (33)',
#  'SCHUYLKILL (107)',
#  'SOMERSET (111)',
#  'BRADFORD (15)',
#  'ELK (47)',
#  'GREENE (59)',
#  'CUMBERLAND (41)',
#  'TIOGA (117)',
#  'CHESTER (29)',
#  'YORK (133)',
#  'BUCKS (17)',
#  'FAYETTE (51)',
#  'CLINTON (35)',
#  'FRANKLIN (55)',
#  'FAYETTE (51)',
#  'HUNTINGDON (61)',
#  'CARBON (25)',
#  'WESTMORELAND (129)',
#  'WYOMING (131)',
#  'PHILADELPHIA (101)',
#  'ALLEGHENY (3)',
#  'LEHIGH (77)',
#  'LANCASTER (71)',
#  'BUCKS (17)',
#  'LEHIGH (77)',
#  'ARMSTRONG (5)',
#  'INDIANA (63)',
#  'MERCER (85)',
#  'BERKS (11)',
#  'UNION (119)',
#  'ALLEGHENY (3)',
#  'ALLEGHENY (3)',
#  'ALLEGHENY (3)',
#  'CRAWFORD (39)',
#  'BUCKS (17)',
#  'MIFFLIN (87)',
#  'FAYETTE (51)',
#  'LANCASTER (71)',
#  'YORK (133)',
#  'BUCKS (17)',
#  'JEFFERSON (65)',
#  'PHILADELPHIA (101)',
#  'PHILADELPHIA (101)',
#  'CAMBRIA (21)',
#  'BRADFORD (15)',
#  'CUMBERLAND (41)',
#  'TIOGA (117)',
#  'CUMBERLAND (41)',
#  'LANCASTER (71)',
#  'CHESTER (29)',
#  'BUTLER (19)',
#  'MONROE (89)',
#  'LYCOMING (81)',
#  'ALLEGHENY (3)',
#  'BUCKS (17)',
#  'PHILADELPHIA (101)',
#  'BERKS (11)',
#  'ARMSTRONG (5)',
#  'LACKAWANNA (69)',
#  'DELAWARE (45)',
#  'BERKS (11)',
#  'BUTLER (19)',
#  'BERKS (11)',
#  'PHILADELPHIA (101)',
#  'CHESTER (29)',
#  'LEHIGH (77)',
#  'LAWRENCE (73)',
#  'LANCASTER (71)',
#  'ERIE (49)',
#  'BUCKS (17)',
#  'CUMBERLAND (41)',
#  'CUMBERLAND (41)',
#  'MCKEAN (83)',
#  'CLEARFIELD (33)',
#  'PHILADELPHIA (101)',
#  'CLEARFIELD (33)',
#  'PHILADELPHIA (101)',
#  'LANCASTER (71)',
#  'ALLEGHENY (3)',
#  'ALLEGHENY (3)',
#  'PHILADELPHIA (101)',
#  'LANCASTER (71)',
#  'SCHUYLKILL (107)',
#  'DELAWARE (45)',
#  'FAYETTE (51)',
#  'LACKAWANNA (69)',
#  'BUCKS (17)',
#  'NORTHUMBERLAND (97)',
#  'WAYNE (127)',
#  'GREENE (59)',
#  'FAYETTE (51)',
#  'BUCKS (17)',
#  'MCKEAN (83)',
#  'LEBANON (75)',
#  'CUMBERLAND (41)',
#  'LAWRENCE (73)',
#  'ALLEGHENY (3)',
#  'INDIANA (63)',
#  'ALLEGHENY (3)',
#  'WASHINGTON (125)',
#  'LUZERNE (79)',
#  'YORK (133)',
#  'YORK (133)',
#  'ARMSTRONG (5)',
#  'ALLEGHENY (3)',
#  'SCHUYLKILL (107)',
#  'FRANKLIN (55)',
#  'CLINTON (35)',
#  'GREENE (59)',
#  'CRAWFORD (39)',
#  'PHILADELPHIA (101)',
#  'LANCASTER (71)',
#  'YORK (133)',
#  'DELAWARE (45)',
#  'CLINTON (35)',
#  'BERKS (11)',
#  'LANCASTER (71)',
#  'FRANKLIN (55)',
#  'CAMBRIA (21)',
#  'MONTGOMERY (91)',
#  'ERIE (49)',
#  'WAYNE (127)',
#  'MONTGOMERY (91)',
#  'MERCER (85)',
#  'LANCASTER (71)',
#  'MONTGOMERY (91)',
#  'BUCKS (17)',
#  'MONTGOMERY (91)',
#  'BUCKS (17)',
#  'WESTMORELAND (129)',
#  'MERCER (85)',
#  'ALLEGHENY (3)',
#  'CAMBRIA (21)',
#  'YORK (133)',
#  'LANCASTER (71)',
#  'CHESTER (29)',
#  'SCHUYLKILL (107)',
#  'MONTGOMERY (91)',
#  'MONTGOMERY (91)',
#  'MONTGOMERY (91)',
#  'GREENE (59)',
#  'LACKAWANNA (69)',
#  'CARBON (25)',
#  'PHILADELPHIA (101)',
#  'CHESTER (29)',
#  'FRANKLIN (55)',
#  'PHILADELPHIA (101)',
#  'PHILADELPHIA (101)',
#  'SUSQUEHANNA (115)',
#  'LEHIGH (77)',
#  'YORK (133)',
#  'BUTLER (19)',
#  'LEHIGH (77)',
#  'FRANKLIN (55)',
#  'ALLEGHENY (3)',
#  'VENANGO (121)',
#  'NORTHAMPTON (95)',
#  'DELAWARE (45)',
#  'WASHINGTON (125)',
#  'BEAVER (7)',
#  'LANCASTER (71)',
#  'DAUPHIN (43)',
#  'DELAWARE (45)',
#  'BUTLER (19)',
#  'ELK (47)',
#  'LYCOMING (81)',
#  'WASHINGTON (125)',
#  'LEHIGH (77)',
#  'LYCOMING (81)',
#  'CLEARFIELD (33)',
#  'PHILADELPHIA (101)',
#  'NORTHAMPTON (95)',
#  'YORK (133)',
#  'BERKS (11)',
#  'CLEARFIELD (33)',
#  'PHILADELPHIA (101)',
#  'CLARION (31)',
#  'ERIE (49)',
#  'ALLEGHENY (3)',
#  'BUCKS (17)',
#  'WESTMORELAND (129)',
#  'WYOMING (131)',
#  'YORK (133)',
#  'PHILADELPHIA (101)',
#  'CLARION (31)',
#  'WESTMORELAND (129)',
#  'CHESTER (29)',
#  'TIOGA (117)',
#  'ERIE (49)',
#  'WESTMORELAND (129)',
#  'BUTLER (19)',
#  'BLAIR (13)',
#  'BUCKS (17)',
#  'PIKE (103)',
#  'FRANKLIN (55)',
#  'BERKS (11)',
#  'LACKAWANNA (69)',
#  'MIFFLIN (87)',
#  'WESTMORELAND (129)',
#  'LYCOMING (81)',
#  'DAUPHIN (43)',
#  'PHILADELPHIA (101)',
#  'SOMERSET (111)',
#  'LANCASTER (71)',
#  'YORK (133)',
#  'BEDFORD (9)',
#  'ERIE (49)',
#  'JEFFERSON (65)',
#  'FAYETTE (51)',
#  'WASHINGTON (125)',
#  'BERKS (11)',
#  'BEAVER (7)',
#  'PHILADELPHIA (101)',
#  'BEDFORD (9)',
#  'BERKS (11)',
#  'PHILADELPHIA (101)',
#  'MONROE (89)',
#  'BERKS (11)',
#  'JEFFERSON (65)',
#  'PIKE (103)',
#  'MONROE (89)',
#  'DAUPHIN (43)',
#  'BRADFORD (15)',
#  'LANCASTER (71)',
#  'LEHIGH (77)',
#  'MONTGOMERY (91)',
#  'ALLEGHENY (3)',
#  'VENANGO (121)',
#  'ALLEGHENY (3)',
#  'SOMERSET (111)',
#  'SOMERSET (111)',
#  'YORK (133)',
#  'LANCASTER (71)',
#  'CLEARFIELD (33)',
#  'MONROE (89)',
#  'TIOGA (117)',
#  'NORTHAMPTON (95)',
#  'SNYDER (109)',
#  'DAUPHIN (43)',
#  'INDIANA (63)',
#  'YORK (133)',
#  'WESTMORELAND (129)',
#  'SCHUYLKILL (107)',
#  'LUZERNE (79)',
#  'MONROE (89)',
#  'BRADFORD (15)',
#  'MONTOUR (93)',
#  'MONTGOMERY (91)',
#  'CAMBRIA (21)',
#  'WESTMORELAND (129)',
#  'BUTLER (19)',
#  'PHILADELPHIA (101)',
#  'YORK (133)',
#  'YORK (133)',
#  'LANCASTER (71)',
#  'PHILADELPHIA (101)',
#  'PHILADELPHIA (101)',
#  'GREENE (59)',
#  'CRAWFORD (39)',
#  'UNION (119)',
#  'NORTHUMBERLAND (97)',
#  'ALLEGHENY (3)',
#  'ALLEGHENY (3)',
#  'WARREN (123)',
#  'MONTGOMERY (91)',
#  'LYCOMING (81)',
#  'BUCKS (17)',
#  'PHILADELPHIA (101)',
#  'ARMSTRONG (5)',
#  'BUCKS (17)',
#  'NORTHAMPTON (95)',
#  'CLINTON (35)',
#  'CAMBRIA (21)',
#  'MONTGOMERY (91)',
#  'COLUMBIA (37)',
#  'LEHIGH (77)',
#  'LACKAWANNA (69)',
#  'YORK (133)',
#  'MONROE (89)',
#  'BLAIR (13)',
#  'NORTHAMPTON (95)',
#  'SCHUYLKILL (107)',
#  'LUZERNE (79)',
#  'WESTMORELAND (129)',
#  'VENANGO (121)',
#  'SCHUYLKILL (107)',
#  'FAYETTE (51)',
#  'CENTRE (27)',
#  'FULTON (57)',
#  'CHESTER (29)',
#  'ALLEGHENY (3)',
#  'VENANGO (121)',
#  'BLAIR (13)',
#  'BERKS (11)',
#  'SOMERSET (111)',
#  'BRADFORD (15)',
#  'LUZERNE (79)',
#  'CHESTER (29)',
#  'WASHINGTON (125)',
#  'CHESTER (29)',
#  'LYCOMING (81)',
#  'CLEARFIELD (33)',
#  'MCKEAN (83)',
#  'TIOGA (117)',
#  'BUCKS (17)',
#  'BEDFORD (9)',
#  'BRADFORD (15)',
#  'SNYDER (109)',
#  'PHILADELPHIA (101)',
#  'WASHINGTON (125)',
#  'DAUPHIN (43)',
#  'BUCKS (17)',
#  'BUCKS (17)',
#  'LUZERNE (79)',
#  'WESTMORELAND (129)',
#  'BERKS (11)',
#  'HUNTINGDON (61)',
#  'ELK (47)',
#  'WAYNE (127)',
#  'LACKAWANNA (69)',
#  'YORK (133)',
#  'CAMBRIA (21)',
#  'WESTMORELAND (129)',
#  'DAUPHIN (43)',
#  'GREENE (59)',
#  'BUCKS (17)',
#  'LANCASTER (71)',
#  'MONTOUR (93)',
#  'CLEARFIELD (33)',
#  'BEAVER (7)',
#  'MERCER (85)',
#  'LUZERNE (79)',
#  'ELK (47)',
#  'CHESTER (29)',
#  'BEDFORD (9)',
#  'DELAWARE (45)',
#  'WESTMORELAND (129)',
#  'WESTMORELAND (129)',
#  'ERIE (49)',
#  'ERIE (49)',
#  'ERIE (49)',
#  'VENANGO (121)',
#  'UNION (119)',
#  'CENTRE (27)',
#  'WESTMORELAND (129)',
#  'NORTHAMPTON (95)',
#  'CHESTER (29)',
#  'ERIE (49)',
#  'MONTGOMERY (91)',
#  'PHILADELPHIA (101)',
#  'WASHINGTON (125)',
#  'CAMBRIA (21)',
#  'PHILADELPHIA (101)',
#  'PHILADELPHIA (101)',
#  'LUZERNE (79)',
#  'SCHUYLKILL (107)',
#  'NORTHUMBERLAND (97)',
#  'LEHIGH (77)',
#  'BUTLER (19)',
#  'PHILADELPHIA (101)',
#  'ALLEGHENY (3)',
#  'HUNTINGDON (61)',
#  'BUCKS (17)',
#  'PHILADELPHIA (101)',
#  'ALLEGHENY (3)',
#  'BERKS (11)',
#  'WASHINGTON (125)',
#  'PHILADELPHIA (101)',
#  'MONTGOMERY (91)',
#  'CENTRE (27)',
#  'MERCER (85)',
#  'YORK (133)',
#  'LANCASTER (71)',
#  'MONROE (89)',
#  'ELK (47)',
#  'CUMBERLAND (41)',
#  'BEDFORD (9)',
#  'MONROE (89)',
#  'BLAIR (13)',
#  'UNION (119)',
#  'LANCASTER (71)',
#  'BEAVER (7)',
#  'LAWRENCE (73)',
#  'LANCASTER (71)',
#  'LUZERNE (79)',
#  'CRAWFORD (39)',
#  'LEHIGH (77)',
#  'BLAIR (13)',
#  'CLEARFIELD (33)',
#  'LYCOMING (81)',
#  'LANCASTER (71)',
#  'PHILADELPHIA (101)',
#  'CLEARFIELD (33)',
#  'LUZERNE (79)',
#  'ERIE (49)',
#  'FRANKLIN (55)',
#  'YORK (133)',
#  'BUCKS (17)',
#  'FAYETTE (51)',
#  'LUZERNE (79)',
#  'LUZERNE (79)',
#  'BUTLER (19)',
#  'FULTON (57)',
#  'BEDFORD (9)',
#  'BUTLER (19)',
#  'COLUMBIA (37)',
#  'WYOMING (131)',
#  'ALLEGHENY (3)',
#  'PERRY (99)',
#  'WAYNE (127)',
#  'CHESTER (29)',
#  'FAYETTE (51)',
#  'FRANKLIN (55)',
#  'CRAWFORD (39)',
#  'BUTLER (19)',
#  'LUZERNE (79)',
#  'BLAIR (13)',
#  'LANCASTER (71)',
#  'LEBANON (75)',
#  'BERKS (11)',
#  'WASHINGTON (125)',
#  'LUZERNE (79)',
#  'CHESTER (29)',
#  'BEDFORD (9)',
#  'LACKAWANNA (69)',
#  'ALLEGHENY (3)',
#  'ALLEGHENY (3)',
#  'INDIANA (63)',
#  'DELAWARE (45)',
#  'ALLEGHENY (3)',
#  'WASHINGTON (125)',
#  'FAYETTE (51)',
#  'LYCOMING (81)',
#  'YORK (133)',
#  'WESTMORELAND (129)',
#  'CARBON (25)',
#  'SCHUYLKILL (107)',
#  'FRANKLIN (55)',
#  'MONROE (89)',
#  'MCKEAN (83)',
#  'TIOGA (117)',
#  'SOMERSET (111)',
#  'WAYNE (127)',
#  'BUTLER (19)',
#  'MONTGOMERY (91)',
#  'MONTGOMERY (91)',
#  'WAYNE (127)',
#  'DELAWARE (45)',
#  'CUMBERLAND (41)',
#  'LANCASTER (71)',
#  'WASHINGTON (125)',
#  'MONTGOMERY (91)',
#  'FRANKLIN (55)',
#  'SOMERSET (111)',
#  'YORK (133)',
#  'PHILADELPHIA (101)',
#  'WASHINGTON (125)',
#  'ADAMS (1)',
#  'PHILADELPHIA (101)',
#  'PHILADELPHIA (101)',
#  'BUTLER (19)',
#  'LUZERNE (79)',
#  'PHILADELPHIA (101)',
#  'UNION (119)',
#  'INDIANA (63)',
#  'WARREN (123)',
#  'BUCKS (17)',
#  'HUNTINGDON (61)',
#  'LANCASTER (71)',
#  'SCHUYLKILL (107)',
#  'BLAIR (13)',
#  'SCHUYLKILL (107)',
#  'SOMERSET (111)',
#  'TIOGA (117)',
#  'BEDFORD (9)',
#  'CLEARFIELD (33)',
#  'BUCKS (17)',
#  'PHILADELPHIA (101)',
#  'PHILADELPHIA (101)',
#  'ERIE (49)',
#  'CAMBRIA (21)',
#  'CUMBERLAND (41)',
#  'BUTLER (19)',
#  'FRANKLIN (55)',
#  'BUCKS (17)',
#  'PHILADELPHIA (101)',
#  'PHILADELPHIA (101)',
#  'MONTGOMERY (91)',
#  'BEAVER (7)',
#  'LACKAWANNA (69)',
#  'SNYDER (109)',
#  'BLAIR (13)',
#  'LANCASTER (71)',
#  'ALLEGHENY (3)',
#  'MONTGOMERY (91)',
#  'CRAWFORD (39)',
#  'COLUMBIA (37)',
#  'LUZERNE (79)',
#  'LEHIGH (77)',
#  'PHILADELPHIA (101)',
#  'DAUPHIN (43)',
#  'NORTHAMPTON (95)',
#  'DELAWARE (45)',
#  'SUSQUEHANNA (115)',
#  'FAYETTE (51)',
#  'FRANKLIN (55)',
#  'BUCKS (17)',
#  'SCHUYLKILL (107)',
#  'COLUMBIA (37)',
#  'ALLEGHENY (3)',
#  'MCKEAN (83)',
#  'LANCASTER (71)',
#  'ALLEGHENY (3)',
#  'COLUMBIA (37)',
#  'MONTGOMERY (91)',
#  'DELAWARE (45)',
#  'FAYETTE (51)',
#  'DELAWARE (45)',
#  'ERIE (49)',
#  'SCHUYLKILL (107)',
#  'CHESTER (29)',
#  'LEHIGH (77)',
#  'PHILADELPHIA (101)',
#  'LACKAWANNA (69)',
#  'ALLEGHENY (3)',
#  'PHILADELPHIA (101)',
#  'INDIANA (63)',
#  'MERCER (85)',
#  'CUMBERLAND (41)',
#  'FAYETTE (51)',
#  'LEHIGH (77)',
#  'LYCOMING (81)',
#  'LANCASTER (71)',
#  'BLAIR (13)',
#  'PIKE (103)',
#  'WARREN (123)',
#  'COLUMBIA (37)',
#  'ERIE (49)',
#  'LANCASTER (71)',
#  'WASHINGTON (125)',
#  'WESTMORELAND (129)',
#  'BEDFORD (9)',
#  'PIKE (103)',
#  'JUNIATA (67)',
#  'NORTHAMPTON (95)',
#  'LYCOMING (81)',
#  'CHESTER (29)',
#  'MIFFLIN (87)',
#  'ADAMS (1)',
#  'CHESTER (29)',
#  'CRAWFORD (39)',
#  'CHESTER (29)',
#  'WASHINGTON (125)',
#  'BUCKS (17)',
#  'MERCER (85)',
#  'WESTMORELAND (129)',
#  'LANCASTER (71)',
#  'MONTGOMERY (91)',
#  'NORTHAMPTON (95)',
#  'LAWRENCE (73)',
#  'LEHIGH (77)',
#  'WYOMING (131)',
#  'LANCASTER (71)',
#  'HUNTINGDON (61)',
#  'ERIE (49)',
#  'YORK (133)',
#  'CENTRE (27)',
#  'PHILADELPHIA (101)',
#  'DAUPHIN (43)',
#  'JUNIATA (67)',
#  'PIKE (103)',
#  'WAYNE (127)',
#  'MONROE (89)',
#  'ERIE (49)',
#  'INDIANA (63)',
#  'YORK (133)',
#  'MONROE (89)',
#  'CRAWFORD (39)',
#  'BUTLER (19)',
#  'LEBANON (75)',
#  'WESTMORELAND (129)',
#  'MONTGOMERY (91)',
#  'FRANKLIN (55)',
#  'SUSQUEHANNA (115)',
#  'LANCASTER (71)',
#  'PHILADELPHIA (101)',
#  'BUTLER (19)',
#  'CLEARFIELD (33)',
#  'ALLEGHENY (3)',
#  'BRADFORD (15)',
#  'CLARION (31)',
#  'MERCER (85)',
#  'BEAVER (7)',
#  'LACKAWANNA (69)',
#  'SNYDER (109)',
#  'LEHIGH (77)',
#  'CARBON (25)',
#  'JEFFERSON (65)',
#  'SUSQUEHANNA (115)',
#  'SOMERSET (111)',
#  'LAWRENCE (73)',
#  'ALLEGHENY (3)',
#  'YORK (133)',
#  'DELAWARE (45)',
#  'NORTHAMPTON (95)',
#  'WAYNE (127)',
#  'GREENE (59)',
#  'CHESTER (29)',
#  'BUTLER (19)',
#  'ARMSTRONG (5)',
#  'PHILADELPHIA (101)',
#  'ALLEGHENY (3)',
#  'PHILADELPHIA (101)',
#  'PHILADELPHIA (101)',
#  'SCHUYLKILL (107)',
#  'PHILADELPHIA (101)',
#  'PHILADELPHIA (101)',
#  'PHILADELPHIA (101)',
#  'FULTON (57)',
#  'LEHIGH (77)',
#  'WESTMORELAND (129)',
#  'SNYDER (109)',
#  'MONROE (89)',
#  'ADAMS (1)',
#  'ALLEGHENY (3)',
#  'LEHIGH (77)',
#  'WESTMORELAND (129)',
#  'BEAVER (7)',
#  'LEHIGH (77)',
#  'ARMSTRONG (5)',
#  'SUSQUEHANNA (115)',
#  'MONTGOMERY (91)',
#  'MONTGOMERY (91)',
#  'COLUMBIA (37)',
#  'PERRY (99)',
#  'PHILADELPHIA (101)',
#  'MONTGOMERY (91)',
#  'ERIE (49)',
#  'LYCOMING (81)',
#  'HUNTINGDON (61)',
#  'LUZERNE (79)',
#  'PHILADELPHIA (101)',
#  'PHILADELPHIA (101)',
#  'DAUPHIN (43)',
#  'PHILADELPHIA (101)',
#  'PHILADELPHIA (101)',
#  'YORK (133)',
#  'CUMBERLAND (41)',
#  'PHILADELPHIA (101)',
#  'LANCASTER (71)',
#  'BLAIR (13)',
#  'CUMBERLAND (41)',
#  'LYCOMING (81)',
#  'TIOGA (117)',
#  'LEHIGH (77)',
#  'DELAWARE (45)',
#  'PHILADELPHIA (101)',
#  'SUSQUEHANNA (115)',
#  'BEAVER (7)',
#  'LACKAWANNA (69)',
#  'CHESTER (29)',
#  'MONROE (89)',
#  'WASHINGTON (125)',
#  'CUMBERLAND (41)',
#  'LAWRENCE (73)',
#  'NORTHAMPTON (95)',
#  'ARMSTRONG (5)',
#  'FRANKLIN (55)',
#  'LANCASTER (71)',
#  'CAMERON (23)',
#  'ERIE (49)',
#  'LUZERNE (79)',
#  'CHESTER (29)',
#  'CUMBERLAND (41)',
#  'BEAVER (7)',
#  'LANCASTER (71)',
#  'BLAIR (13)',
#  'YORK (133)',
#  'LANCASTER (71)',
#  'BUCKS (17)',
#  'ERIE (49)',
#  'WASHINGTON (125)',
#  'WASHINGTON (125)',
#  'PHILADELPHIA (101)',
#  'MONTGOMERY (91)',
#  'MERCER (85)',
#  'BERKS (11)',
#  'BERKS (11)',
#  'ERIE (49)',
#  'FAYETTE (51)',
#  'MIFFLIN (87)',
#  'YORK (133)',
#  'FULTON (57)',
#  'FRANKLIN (55)',
#  'LEHIGH (77)',
#  'LANCASTER (71)',
#  'LANCASTER (71)',
#  'NORTHUMBERLAND (97)',
#  'LEHIGH (77)',
#  'YORK (133)',
#  'SCHUYLKILL (107)',
#  'DELAWARE (45)',
#  'ALLEGHENY (3)',
#  'MONTGOMERY (91)',
#  'CARBON (25)',
#  'FRANKLIN (55)',
#  'WASHINGTON (125)',
#  'SOMERSET (111)',
#  'CLARION (31)',
#  'BUCKS (17)',
#  'FRANKLIN (55)',
#  'VENANGO (121)',
#  'FRANKLIN (55)',
#  'LANCASTER (71)',
#  'ALLEGHENY (3)',
#  'CENTRE (27)',
#  'BUTLER (19)',
#  'WESTMORELAND (129)',
#  'ALLEGHENY (3)',
#  'LUZERNE (79)',
#  'WAYNE (127)',
#  'PIKE (103)',
#  'PHILADELPHIA (101)',
#  'DELAWARE (45)',
#  'PERRY (99)',
#  'ALLEGHENY (3)',
#  'PIKE (103)',
#  'LUZERNE (79)',
#  'DAUPHIN (43)',
#  'CHESTER (29)',
#  'BLAIR (13)',
#  'BEDFORD (9)',
#  'DAUPHIN (43)',
#  'LUZERNE (79)',
#  'LANCASTER (71)',
#  'LANCASTER (71)',
#  'CRAWFORD (39)',
#  'BUCKS (17)',
#  'BUTLER (19)',
#  'BUCKS (17)',
#  'MONTGOMERY (91)',
#  'NORTHAMPTON (95)',
#  'LANCASTER (71)',
#  'PHILADELPHIA (101)',
#  'CRAWFORD (39)',
#  'ERIE (49)',
#  'WESTMORELAND (129)',
#  'SOMERSET (111)',
#  'CHESTER (29)',
#  'PHILADELPHIA (101)',
#  'VENANGO (121)',
#  'BUCKS (17)',
#  'PHILADELPHIA (101)',
#  'FULTON (57)',
#  'CENTRE (27)',
#  'LANCASTER (71)',
#  'CHESTER (29)',
#  'MONROE (89)',
#  'NORTHUMBERLAND (97)',
#  'CLEARFIELD (33)',
#  'PIKE (103)',
#  'HUNTINGDON (61)',
#  'FRANKLIN (55)',
#  'LYCOMING (81)',
#  'LUZERNE (79)',
#  'SCHUYLKILL (107)',
#  'NORTHAMPTON (95)',
#  'DAUPHIN (43)',
#  'CLARION (31)',
#  'LEHIGH (77)',
#  'BERKS (11)',
#  'BUCKS (17)',
#  'PHILADELPHIA (101)',
#  'ALLEGHENY (3)',
#  'YORK (133)',
#  'MONROE (89)',
#  'PERRY (99)',
#  'FRANKLIN (55)',
#  'LUZERNE (79)',
#  'NORTHAMPTON (95)',
#  'PHILADELPHIA (101)',
#  'LEHIGH (77)',
#  'BUTLER (19)',
#  'WESTMORELAND (129)',
#  'BEDFORD (9)',
#  'PHILADELPHIA (101)',
#  'MONROE (89)',
#  'LUZERNE (79)',
#  'SCHUYLKILL (107)',
#  'BUCKS (17)',
#  'CHESTER (29)',
#  'CAMBRIA (21)',
#  'LEHIGH (77)',
#  'LANCASTER (71)',
#  'SCHUYLKILL (107)',
#  'LANCASTER (71)',
#  'LANCASTER (71)',
#  'LANCASTER (71)',
#  'WASHINGTON (125)',
#  'BUCKS (17)',
#  'ERIE (49)',
#  'LUZERNE (79)',
#  'GREENE (59)',
#  'LEHIGH (77)',
#  'BUCKS (17)',
#  'CUMBERLAND (41)',
#  'SCHUYLKILL (107)',
#  'LANCASTER (71)',
#  'ARMSTRONG (5)',
#  'PHILADELPHIA (101)',
#  'ALLEGHENY (3)',
#  'LUZERNE (79)',
#  'MONTGOMERY (91)',
#  'PHILADELPHIA (101)',
#  'YORK (133)',
#  'PHILADELPHIA (101)',
#  'CUMBERLAND (41)',
#  'FRANKLIN (55)',
#  'ALLEGHENY (3)',
#  'LEHIGH (77)',
#  'LEHIGH (77)',
#  'ALLEGHENY (3)',
#  ...]

# %%
PA_dict = {
    "county_name": county,
    "Crash_date":CrashDate ,
    "Fatals": Fatals,
    "Total_vehicles":TotalVehicles
}
PA_data =pd.DataFrame(PA_dict)
PA_data
# Out:
#            county_name                  Crash_date  Fatals  Total_vehicles
# 0     SCHUYLKILL (107)  /Date(1389099660000-0500)/       1               1
# 1         CAMBRIA (21)  /Date(1388905080000-0500)/       1               1
# 2     SCHUYLKILL (107)  /Date(1388951400000-0500)/       1               1
# 3           PERRY (99)  /Date(1389790560000-0500)/       1               1
# 4        WYOMING (131)  /Date(1388721000000-0500)/       1               1
# ...                ...                         ...     ...             ...
# 5473       GREENE (59)  /Date(1530383220000-0400)/       1               3
# 5474       GREENE (59)  /Date(1536008700000-0400)/       1               2
# 5475       MCKEAN (83)  /Date(1536194160000-0400)/       1               2
# 5476     LYCOMING (81)  /Date(1546221480000-0500)/       1               1
# 5477        PIKE (103)  /Date(1536164760000-0400)/       1               2
#
# [5478 rows x 4 columns]

# %%
Philadelphia_county=PA_data.loc[PA_data["county_name"]=="PHILADELPHIA (101)",:]

# %%
Philadelphia_county
# Out:
#              county_name                  Crash_date  Fatals  Total_vehicles
# 30    PHILADELPHIA (101)  /Date(1390794300000-0500)/       1               1
# 31    PHILADELPHIA (101)  /Date(1389050280000-0500)/       1               1
# 63    PHILADELPHIA (101)  /Date(1391352360000-0500)/       1               1
# 70    PHILADELPHIA (101)  /Date(1393044420000-0500)/       1               1
# 73    PHILADELPHIA (101)  /Date(1392714180000-0500)/       1               2
# ...                  ...                         ...     ...             ...
# 5353  PHILADELPHIA (101)  /Date(1540144020000-0400)/       1               4
# 5354  PHILADELPHIA (101)  /Date(1541915400000-0500)/       1               1
# 5360  PHILADELPHIA (101)  /Date(1546303620000-0500)/       1               1
# 5370  PHILADELPHIA (101)  /Date(1541913000000-0500)/       1               1
# 5385  PHILADELPHIA (101)  /Date(1542826500000-0500)/       1               3
#
# [458 rows x 4 columns]

# %%
Philadelphia_county.to_csv("output counties/Philadelphia County Output")
